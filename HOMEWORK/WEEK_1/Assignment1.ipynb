# %% [markdown]
# #### Write a MatLab or Python program to answer the following questions in sequence:

# %% [markdown]
# 1. Read in the CSV file “ML_HW_Data_FisherIris.csv” into a matrix named as
# “Iris”. Please do NOT output the whole matrix in our answer.

# %%
import pandas as pd

# 1. load data

Iris = pd.read_csv("ML_HW_Data_FisherIris.csv")

# %% [markdown]
# 2. Display total number of rows and total number of columns of the matrix “Iris”

# %%
# 2. explore data
print(f"Total rows and columns: {Iris.shape}")
# Out:
# Total rows and columns: (149, 5)

# %% [markdown]
# 3. Display all the row numbers (i.e. record numbers) that have the 5th column less than 0.

# %%
negative_rows = Iris[Iris.iloc[:, 4] < 0].index.tolist()
print(f"Row numbers with 5th column < 0: {negative_rows}")
# Out:
# Row numbers with 5th column < 0: []

# %% [markdown]
# 4. Remove the rows with the 5th column less than 0 from the “Iris” matrix. Please do **NOT** output or include the whole resulting matrix in our answer.

# %%
Iris = Iris.drop(negative_rows)

# %% [markdown]
# 5. Display total number of rows and total number of columns of the “Iris” matrix again

# %%
print(f"cleaned matrix shape: {Iris.shape}")
# Out:
# cleaned matrix shape: (143, 5)

# %% [markdown]
# 6. Copy the first 4 columns in the new “Iris” matrix into a new matrix “X”. Please do **NOT** output or include the whole resulting matrix in our answer.

# %%
X = Iris.iloc[:, 0:4]

# %% [markdown]
# 7. Copy the 5th columns in the new “Iris” matrix into a new variable (or matrix) “Y”. Please do **NOT** output or include the whole resulting matrix in our answer.

# %%
Y = Iris.iloc[:, 4]

# %% [markdown]
# 8. Display the maximum value and the minimum value of EACH column in “X”.

# %%
print("max values per column:\n", X.max())

print("min values per column:\n", X.min())
# Out:
# max values per column:
#  2     25
# 14    69
# 33    44
# 50    79
# dtype: int64
# min values per column:
#  2      1
# 14    10
# 33    20
# 50    43
# dtype: int64

# %% [markdown]
# 9. Display total number of elements (i.e. items) in the third column of the matrix “X” that are greater than 36.

# %%
count_over_36 = (X.iloc[:, 2] > 36).sum()
print(f"Total elements in 3rd column > 36: {count_over_36}")
# Out:
# Total elements in 3rd column > 36: 15
